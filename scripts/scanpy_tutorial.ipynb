# %%
# !pip install mudatasets
# Out:
# Requirement already satisfied: mudatasets in /home/abydanov/.local/lib/python3.8/site-packages (0.0.2)
# Requirement already satisfied: requests in /home/abydanov/.local/lib/python3.8/site-packages (from mudatasets) (2.32.3)
# Requirement already satisfied: tqdm in /home/abydanov/.local/lib/python3.8/site-packages (from mudatasets) (4.66.5)
# Requirement already satisfied: mudata in /home/abydanov/.local/lib/python3.8/site-packages (from mudatasets) (0.2.3)
# Requirement already satisfied: muon in /home/abydanov/.local/lib/python3.8/site-packages (from mudatasets) (0.1.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/abydanov/.local/lib/python3.8/site-packages (from requests->mudatasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->mudatasets) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/abydanov/.local/lib/python3.8/site-packages (from requests->mudatasets) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->mudatasets) (1.26.2)
# Requirement already satisfied: pandas in /home/abydanov/.local/lib/python3.8/site-packages (from mudata->mudatasets) (2.0.3)
# Requirement already satisfied: anndata>=0.8 in /home/abydanov/.local/lib/python3.8/site-packages (from mudata->mudatasets) (0.9.2)
# Requirement already satisfied: h5py in /home/abydanov/.local/lib/python3.8/site-packages (from mudata->mudatasets) (3.11.0)
# Requirement already satisfied: numpy in /home/abydanov/.local/lib/python3.8/site-packages (from mudata->mudatasets) (1.24.4)
# Requirement already satisfied: scanpy in /home/abydanov/.local/lib/python3.8/site-packages (from muon->mudatasets) (1.9.8)
# Requirement already satisfied: scikit-learn in /home/abydanov/.local/lib/python3.8/site-packages (from muon->mudatasets) (1.3.2)
# Requirement already satisfied: umap-learn in /home/abydanov/.local/lib/python3.8/site-packages (from muon->mudatasets) (0.5.7)
# Requirement already satisfied: seaborn in /home/abydanov/.local/lib/python3.8/site-packages (from muon->mudatasets) (0.13.2)
# Requirement already satisfied: numba in /home/abydanov/.local/lib/python3.8/site-packages (from muon->mudatasets) (0.58.1)
# Requirement already satisfied: protobuf in /usr/lib/python3/dist-packages (from muon->mudatasets) (3.6.1)
# Requirement already satisfied: matplotlib in /home/abydanov/.local/lib/python3.8/site-packages (from muon->mudatasets) (3.7.5)
# Requirement already satisfied: tzdata>=2022.1 in /home/abydanov/.local/lib/python3.8/site-packages (from pandas->mudata->mudatasets) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /home/abydanov/.local/lib/python3.8/site-packages (from pandas->mudata->mudatasets) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/abydanov/.local/lib/python3.8/site-packages (from pandas->mudata->mudatasets) (2.9.0.post0)
# Requirement already satisfied: packaging>=20 in /home/abydanov/.local/lib/python3.8/site-packages (from anndata>=0.8->mudata->mudatasets) (24.1)
# Requirement already satisfied: natsort in /home/abydanov/.local/lib/python3.8/site-packages (from anndata>=0.8->mudata->mudatasets) (8.4.0)
# Requirement already satisfied: scipy>1.4 in /home/abydanov/.local/lib/python3.8/site-packages (from anndata>=0.8->mudata->mudatasets) (1.10.1)
# Requirement already satisfied: networkx>=2.3 in /home/abydanov/.local/lib/python3.8/site-packages (from scanpy->muon->mudatasets) (2.8.8)
# Requirement already satisfied: patsy in /home/abydanov/.local/lib/python3.8/site-packages (from scanpy->muon->mudatasets) (1.0.1)
# Requirement already satisfied: joblib in /home/abydanov/.local/lib/python3.8/site-packages (from scanpy->muon->mudatasets) (1.4.2)
# Requirement already satisfied: get-annotations; python_version < "3.10" in /home/abydanov/.local/lib/python3.8/site-packages (from scanpy->muon->mudatasets) (0.1.2)
# Requirement already satisfied: session-info in /home/abydanov/.local/lib/python3.8/site-packages (from scanpy->muon->mudatasets) (1.0.0)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /home/abydanov/.local/lib/python3.8/site-packages (from scanpy->muon->mudatasets) (0.14.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/abydanov/.local/lib/python3.8/site-packages (from scikit-learn->muon->mudatasets) (3.5.0)
# Requirement already satisfied: pynndescent>=0.5 in /home/abydanov/.local/lib/python3.8/site-packages (from umap-learn->muon->mudatasets) (0.5.13)
# Requirement already satisfied: importlib-metadata; python_version < "3.9" in /home/abydanov/.local/lib/python3.8/site-packages (from numba->muon->mudatasets) (8.4.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /home/abydanov/.local/lib/python3.8/site-packages (from numba->muon->mudatasets) (0.41.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/abydanov/.local/lib/python3.8/site-packages (from matplotlib->muon->mudatasets) (10.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/abydanov/.local/lib/python3.8/site-packages (from matplotlib->muon->mudatasets) (6.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /home/abydanov/.local/lib/python3.8/site-packages (from matplotlib->muon->mudatasets) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/abydanov/.local/lib/python3.8/site-packages (from matplotlib->muon->mudatasets) (1.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in /home/abydanov/.local/lib/python3.8/site-packages (from matplotlib->muon->mudatasets) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/abydanov/.local/lib/python3.8/site-packages (from matplotlib->muon->mudatasets) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/abydanov/.local/lib/python3.8/site-packages (from matplotlib->muon->mudatasets) (3.1.4)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->mudata->mudatasets) (1.15.0)
# Requirement already satisfied: stdlib-list in /home/abydanov/.local/lib/python3.8/site-packages (from session-info->scanpy->muon->mudatasets) (0.10.0)
# Requirement already satisfied: zipp>=0.5 in /home/abydanov/.local/lib/python3.8/site-packages (from importlib-metadata; python_version < "3.9"->numba->muon->mudatasets) (3.20.2)

# %%
# !pip install pooch
# Out:
# Collecting pooch
#   Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 106 kB/s eta 0:00:01
# Requirement already satisfied: requests>=2.19.0 in /home/abydanov/.local/lib/python3.8/site-packages (from pooch) (2.32.3)
# Requirement already satisfied: packaging>=20.0 in /home/abydanov/.local/lib/python3.8/site-packages (from pooch) (24.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/abydanov/.local/lib/python3.8/site-packages (from pooch) (4.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.19.0->pooch) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/abydanov/.local/lib/python3.8/site-packages (from requests>=2.19.0->pooch) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/abydanov/.local/lib/python3.8/site-packages (from requests>=2.19.0->pooch) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.19.0->pooch) (1.26.2)
# Installing collected packages: pooch
# Successfully installed pooch-1.8.2

# %%
import anndata
import matplotlib.pyplot as plt
import numpy as np
import pooch
import scanpy as sc

# %%
sc.settings.set_figure_params(dpi=50, facecolor="white")

# %%
datapath = pooch.retrieve(
    url="https://figshare.com/ndownloader/files/40067737",
    known_hash="md5:b80deb0997f96b45d06f19c694e46243",
    path="./data",
    fname="scverse-getting-started-anndata-pbmc3k_processed.h5ad",
)

# %%
adata = anndata.read_h5ad(datapath)

# %%
adata.X
# Out:
# <2638x11505 sparse matrix of type '<class 'numpy.float32'>'
# 	with 2076576 stored elements in Compressed Sparse Row format>

# %%
# look at the non-zero values in the data
print(adata.X.data)
# look at their indices / positions in the data matrix
print(adata.X.indices)
# compute the fraction of non-zero entries
print(adata.X.nnz / np.product(adata.X.shape))
# Out:
# [0.6496621 0.6496621 1.0402015 ... 0.7506172 0.7506172 1.4713064]
# [   19    52    58 ... 11498 11501 11504]
# 0.068420527186156

# %%
adata.layers["raw"].data
# Out:
# array([1, 1, 2, ..., 1, 1, 3])

# %%
# copy raw counts to new layer
adata.layers["counts_per_million"] = adata.layers["raw"].copy()
# normalize the new layer to counts-per-million
sc.pp.normalize_total(adata, target_sum=10**6, layer="counts_per_million")
print(adata.layers)
# Out:
# Layers with keys: raw, counts_per_million

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 2.5))
genes_of_interest = ["CD8A", "CD4", "KLRB1"]
sc.pl.matrixplot(
    adata,
    groupby="louvain_cell_types",
    var_names=genes_of_interest,
    layer="counts_per_million",  ## set which layer to plot
    ax=ax1,
    show=False,
)
ax1.set_title("CPM normalization")

sc.pl.matrixplot(
    adata,
    groupby="louvain_cell_types",
    var_names=genes_of_interest,
    layer="raw",  ## set which layer to plot
    ax=ax2,
    show=False,
)
ax2.set_title("raw counts")
plt.tight_layout();

# %%
adata.obs
# Out:
#                   n_genes  percent_mito  n_counts louvain_cell_types
# cell_barcode
# AAACATACAACCAC-1      781      0.030178    2419.0        CD4 T cells
# AAACATTGAGCTAC-1     1352      0.037936    4903.0            B cells
# AAACATTGATCAGC-1     1131      0.008897    3147.0        CD4 T cells
# AAACCGTGCTTCCG-1      960      0.017431    2639.0    CD14+ Monocytes
# AAACCGTGTATGCG-1      522      0.012245     980.0           NK cells
# ...                   ...           ...       ...                ...
# TTTCGAACTCTCAT-1     1155      0.021104    3459.0    CD14+ Monocytes
# TTTCTACTGAGGCA-1     1227      0.009294    3443.0            B cells
# TTTCTACTTCCTCG-1      622      0.021971    1684.0            B cells
# TTTGCATGAGAGGC-1      454      0.020548    1022.0            B cells
# TTTGCATGCCTCAC-1      724      0.008065    1984.0        CD4 T cells
#
# [2638 rows x 4 columns]

# %%
print(sum(adata.obs["louvain_cell_types"] == "B cells"))
# Out:
# 342

# %%
from warnings import filterwarnings

# for datasets
import mudatasets
import muon as mu
import pandas as pd
import scanpy as sc

filterwarnings("ignore", category=FutureWarning)
filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)

# %%
sc.set_figure_params(fontsize=18, figsize=[6, 6])

# %%
## Working with backed AnnData objects
# Let’s load an anndata object in memory

adata = sc.datasets.pbmc3k_processed()
adata = adata.raw.to_adata()  # Store raw counts in adata.X

# %%
# Convenience method for computing the size of objects
def print_size_in_MB(x):
    print(f"{x.__sizeof__() / 1e6:.3} MB")

# %%
print_size_in_MB(adata)
# Out:
# 21.2 MB

# %%
# Now let’s save this object in .h5ad format and re-load it in backed (on-disk) mode.

adata.write_h5ad("./data/pbmc3k_processed_raw.h5ad")
adata = sc.read_h5ad("./data/pbmc3k_processed_raw.h5ad", backed=True)

print_size_in_MB(adata)
# Out:
# 3.28 MB

# %%
adata.isbacked
# Out:
# True

# %%
adata.filename
# Out:
# PosixPath('data/pbmc3k_processed_raw.h5ad')

# %%
sc.pl.umap(adata, color=["louvain", "CD4"], wspace=0.6)
# Out:
# /home/abydanov/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.dotplot(adata, var_names=["NKG7", "CD4", "CD3E"], groupby="louvain")
# Out:
# /home/abydanov/.local/lib/python3.8/site-packages/scanpy/plotting/_dotplot.py:747: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
sc.pp.neighbors(adata, n_neighbors=20)
sc.tl.umap(adata)

# %%
# !pip install leidenalg
# !pip install texttable
# !pip install --upgrade --force-reinstall leidenalg igraph
# Out:
# Requirement already satisfied: leidenalg in /home/abydanov/.local/lib/python3.8/site-packages (0.10.2)
# Requirement already satisfied: igraph<0.12,>=0.10.0 in /home/abydanov/.local/lib/python3.8/site-packages (from leidenalg) (0.11.8)
# Requirement already satisfied: texttable>=1.6.2 in /usr/lib/python3/dist-packages (from igraph<0.12,>=0.10.0->leidenalg) (1.6.2)
# Requirement already satisfied: texttable in /usr/lib/python3/dist-packages (1.6.2)
# Collecting leidenalg
#   Using cached leidenalg-0.10.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# Collecting igraph
#   Using cached igraph-0.11.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Collecting texttable>=1.6.2
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph, leidenalg
#   Attempting uninstall: igraph
#     Found existing installation: igraph 0.11.8
#     Uninstalling igraph-0.11.8:
#       Successfully uninstalled igraph-0.11.8
#   WARNING: The script igraph is installed in '/home/abydanov/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: leidenalg
#     Found existing installation: leidenalg 0.10.2
#     Uninstalling leidenalg-0.10.2:
#       Successfully uninstalled leidenalg-0.10.2
# Successfully installed igraph-0.11.8 leidenalg-0.10.2 texttable-1.7.0

# %%
sc.tl.leiden(adata, resolution=0.5, key_added="leiden_res0.5")

# %%
adata.obs
# Out:
#                   n_genes  percent_mito  n_counts          louvain  \
# index
# AAACATACAACCAC-1      781      0.030178    2419.0      CD4 T cells
# AAACATTGAGCTAC-1     1352      0.037936    4903.0          B cells
# AAACATTGATCAGC-1     1131      0.008897    3147.0      CD4 T cells
# AAACCGTGCTTCCG-1      960      0.017431    2639.0  CD14+ Monocytes
# AAACCGTGTATGCG-1      522      0.012245     980.0         NK cells
# ...                   ...           ...       ...              ...
# TTTCGAACTCTCAT-1     1155      0.021104    3459.0  CD14+ Monocytes
# TTTCTACTGAGGCA-1     1227      0.009294    3443.0          B cells
# TTTCTACTTCCTCG-1      622      0.021971    1684.0          B cells
# TTTGCATGAGAGGC-1      454      0.020548    1022.0          B cells
# TTTGCATGCCTCAC-1      724      0.008065    1984.0      CD4 T cells
#
#                  leiden_res0.5
# index
# AAACATACAACCAC-1             0
# AAACATTGAGCTAC-1             3
# AAACATTGATCAGC-1             0
# AAACCGTGCTTCCG-1             1
# AAACCGTGTATGCG-1             2
# ...                        ...
# TTTCGAACTCTCAT-1             1
# TTTCTACTGAGGCA-1             3
# TTTCTACTTCCTCG-1             3
# TTTGCATGAGAGGC-1             3
# TTTGCATGCCTCAC-1             0
#
# [2638 rows x 5 columns]

# %%
sc.pl.umap(adata, color=["louvain", "leiden_res0.5"])
# Out:
# /home/abydanov/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/abydanov/.local/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
# Extracting a subset of AnnData

T_clusters = ["CD4 T cells", "CD8 T cells"]
adata_subset = adata[adata.obs["louvain"].isin(T_clusters)].to_memory()

# %%
adata_subset
# Out:
# AnnData object with n_obs × n_vars = 1460 × 13714
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'louvain', 'leiden_res0.5'
#     var: 'n_cells'
#     uns: 'draw_graph', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'rank_genes_groups', 'umap', 'leiden', 'leiden_res0.5_colors'
#     obsm: 'X_draw_graph_fr', 'X_pca', 'X_tsne', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
adata_subset.isbacked
# Out:
# False

# %%
# If we want to keep working in backed mode with this data subset, we can copy it specifying a new .h5ad file on disk where this will be saved.

adata_subset = adata[adata.obs["louvain"].isin(T_clusters)].copy(filename="./data/pbmc3k_processed_CD4Tcells.h5ad")

# %%
adata_subset.isbacked

# %%
sc.pp.normalize_total(adata)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /scratch/ipykernel_1124054/564242233.py in <module>
# ----> 1 sc.pp.normalize_total(adata)
#
# ~/.local/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py in normalize_total(adata, target_sum, exclude_highly_expressed, max_fraction, key_added, layer, layers, layer_norm, inplace, copy)
#     188         counts_per_cell = X[:, gene_subset].sum(1)
#     189     else:
# --> 190         counts_per_cell = X.sum(1)
#     191     start = logg.info(msg)
#     192     counts_per_cell = np.ravel(counts_per_cell)
#
# AttributeError: 'SparseDataset' object has no attribute 'sum'

# %%
adata.X[:, 0 : adata.n_vars]
# Out:
# <2638x13714 sparse matrix of type '<class 'numpy.float32'>'
# 	with 2238732 stored elements in Compressed Sparse Row format>

# %%
adata.write_h5ad()
